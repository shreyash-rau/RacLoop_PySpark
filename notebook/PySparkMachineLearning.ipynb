# %%
# Download necessary libraries
# !pip install pyspark
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.4.1)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %%
# Import necessary libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import when, col, round, mean
from pyspark.ml.feature import StringIndexer, VectorAssembler
from pyspark.ml.classification import LogisticRegression
from pyspark.ml import Pipeline
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %%
# Create a Spark session
spark = SparkSession.builder.appName("MachineLearning").getOrCreate()

# %%
# Load the dataset
data = spark.read.format('csv').options(header = 'True', inferSchema = True).load("C:\Users\Shreyash Raut\Downloads\Heart-Disease-Prediction-Using-Apache-Spark-main\Heart-Disease-Prediction-Using-Apache-Spark-main\data\Data_set.csv")

# Preview of the data
data.toPandas()
# Out:
#       ID   Age  Sex  Angina  Blood_Pressure  Cholesterol  Glycemia  ECG  \
# 0      1  63.0  1.0     1.0           145.0        233.0       1.0  2.0
# 1      2  67.0  1.0     4.0           160.0        286.0       0.0  2.0
# 2      3  67.0  1.0     4.0           120.0        229.0       0.0  2.0
# 3      4  37.0  1.0     3.0           130.0        250.0       0.0  0.0
# 4      5  41.0  0.0     2.0           130.0        204.0       0.0  2.0
# ..   ...   ...  ...     ...             ...          ...       ...  ...
# 298  299  45.0  1.0     1.0           110.0        264.0       0.0  0.0
# 299  300  68.0  1.0     4.0           144.0        193.0       1.0  0.0
# 300  301  57.0  1.0     4.0           130.0        131.0       0.0  0.0
# 301  302  57.0  0.0     2.0           130.0        236.0       0.0  2.0
# 302  303  38.0  1.0     3.0           138.0        175.0       0.0  0.0
#
#      Heart_Rate  Angina_After_Sport  ECG_Angina  ECG_Slope Fluoroscopy  \
# 0         150.0                 0.0         2.3        3.0         0.0
# 1         108.0                 1.0         1.5        2.0         3.0
# 2         129.0                 1.0         2.6        2.0         2.0
# 3         187.0                 0.0         3.5        3.0         0.0
# 4         172.0                 0.0         1.4        1.0         0.0
# ..          ...                 ...         ...        ...         ...
# 298       132.0                 0.0         1.2        2.0         0.0
# 299       141.0                 0.0         3.4        2.0         2.0
# 300       115.0                 1.0         1.2        2.0         1.0
# 301       174.0                 0.0         0.0        2.0         1.0
# 302       173.0                 0.0         0.0        1.0           ?
#
#     Thalassaemia  Disease
# 0            6.0        0
# 1            3.0        2
# 2            7.0        1
# 3            3.0        0
# 4            3.0        0
# ..           ...      ...
# 298          7.0        1
# 299          7.0        2
# 300          7.0        3
# 301          3.0        1
# 302          3.0        0
#
# [303 rows x 15 columns]

# %% [markdown]
# **Meaning of the features :**
#
# - Age : age (years)
# - Sex : gender (0 = Female, 1 = Male)
# - Angina : chest pain (1 = Stable angina, 2 = Unstable angina, 3 = Other pains, 4 = Asymptomatic)
# - Blood_Pressure : resting blood pressure (mmHg)
# - Cholesterol : cholesterol levels (mg/dl)
# - Glycemia : fasting blood sugar (0 = Less than 120 mg/dl, 1 = More than 120 mg/dl)
# - ECG : electrocardiogram results (0 = Normal, 1 = Anomalies, 2 = Hypertrophy)
# - Heart_Rate : maximum heart rate reached
# - Angina_After_Sport : angina pectoris after physical exertion (0 = no, 1 = yes)
# - ECG_Angina : measure of the angina pectoris on the electrocardiogram
# - ECG_Slope : slope on the electrocardiogram (1 = Rising, 2 = Stable, 3 = Falling)
# - Fluoroscopy : fluoroscopy results (0 = No anomaly, 1 = Low, 2 = Medium, 3 = High)
# - Thalassemia : presence of a Thalassaemia (3 = No, 6 = Thalassaemia under control, 7 = Unstable Thalassaemia)
# - Disease : presence of a cardiovascular disease (0 = No, 1/2/3/4 = Yes)

# %%
# Count of "?" values in each column
for col_name in data.columns:
  print(col_name, ": ", data.filter(data[col_name] == "?").count())
# Out:
# ID :  0
# Age :  0
# Sex :  0
# Angina :  0
# Blood_Pressure :  0
# Cholesterol :  0
# Glycemia :  0
# ECG :  0
# Heart_Rate :  0
# Angina_After_Sport :  0
# ECG_Angina :  0
# ECG_Slope :  0
# Fluoroscopy :  4
# Thalassaemia :  2
# Disease :  0

# %%
# Remove records with "?" values in "Fluoroscopy" and "Thalassaemia" columns
data = data.filter((data.Fluoroscopy != "?") & (data.Thalassaemia != "?"))

# %%
# Recoding certain variables
data = data.withColumn("Sex", when(col("Sex") == 0, "Female").otherwise("Male"))
data = data.withColumn("Angina", when(col("Angina") == 1, "Stable angina").when(col("Angina") == 2, "Unstable angina").when(col("Angina") == 3, "Other pains").otherwise("Asymptomatic"))
data = data.withColumn("Glycemia", when(col("Glycemia") == 0, "Less than 120 mg/dl").otherwise("More than 120 mg/dl"))
data = data.withColumn("ECG", when(col("ECG") == 0, "Normal").when(col("ECG") == 1, "Anomalies").otherwise("Hypertrophy"))
data = data.withColumn("Angina_After_Sport", when(col("Angina_After_Sport") == 0, "No").otherwise("Yes"))
data = data.withColumn("ECG_Slope", when(col("ECG_Slope") == 1, "Rising").when(col("ECG_Slope") == 2, "Stable").otherwise("Falling"))
data = data.withColumn("Fluoroscopy", when(col("Fluoroscopy") == "0.0", "No anomaly").when(col("Fluoroscopy") == "1.0", "Low").when(col("Fluoroscopy") == "2.0", "Medium").otherwise("High"))
data = data.withColumn("Thalassaemia", when(col("Thalassaemia") == "3.0", "No").when(col("Thalassaemia") == "6.0", "Thalassaemia under control").otherwise("Unstable Thalassaemia"))
data = data.withColumn("Disease", when(col("Disease") == 0, "No").otherwise("Yes"))

# Preview of the data
data.toPandas()
# Out:
#       ID   Age     Sex           Angina  Blood_Pressure  Cholesterol  \
# 0      1  63.0    Male    Stable angina           145.0        233.0
# 1      2  67.0    Male     Asymptomatic           160.0        286.0
# 2      3  67.0    Male     Asymptomatic           120.0        229.0
# 3      4  37.0    Male      Other pains           130.0        250.0
# 4      5  41.0  Female  Unstable angina           130.0        204.0
# ..   ...   ...     ...              ...             ...          ...
# 292  298  57.0  Female     Asymptomatic           140.0        241.0
# 293  299  45.0    Male    Stable angina           110.0        264.0
# 294  300  68.0    Male     Asymptomatic           144.0        193.0
# 295  301  57.0    Male     Asymptomatic           130.0        131.0
# 296  302  57.0  Female  Unstable angina           130.0        236.0
#
#                 Glycemia          ECG  Heart_Rate Angina_After_Sport  \
# 0    More than 120 mg/dl  Hypertrophy       150.0                 No
# 1    Less than 120 mg/dl  Hypertrophy       108.0                Yes
# 2    Less than 120 mg/dl  Hypertrophy       129.0                Yes
# 3    Less than 120 mg/dl       Normal       187.0                 No
# 4    Less than 120 mg/dl  Hypertrophy       172.0                 No
# ..                   ...          ...         ...                ...
# 292  Less than 120 mg/dl       Normal       123.0                Yes
# 293  Less than 120 mg/dl       Normal       132.0                 No
# 294  More than 120 mg/dl       Normal       141.0                 No
# 295  Less than 120 mg/dl       Normal       115.0                Yes
# 296  Less than 120 mg/dl  Hypertrophy       174.0                 No
#
#      ECG_Angina ECG_Slope Fluoroscopy                Thalassaemia Disease
# 0           2.3   Falling  No anomaly  Thalassaemia under control      No
# 1           1.5    Stable        High                          No     Yes
# 2           2.6    Stable      Medium       Unstable Thalassaemia     Yes
# 3           3.5   Falling  No anomaly                          No      No
# 4           1.4    Rising  No anomaly                          No      No
# ..          ...       ...         ...                         ...     ...
# 292         0.2    Stable  No anomaly       Unstable Thalassaemia     Yes
# 293         1.2    Stable  No anomaly       Unstable Thalassaemia     Yes
# 294         3.4    Stable      Medium       Unstable Thalassaemia     Yes
# 295         1.2    Stable         Low       Unstable Thalassaemia     Yes
# 296         0.0    Stable         Low                          No     Yes
#
# [297 rows x 15 columns]

# %%
# Display count, mean, stddev, min, max
data.describe().show()
# Out:
# +-------+------------------+-----------------+------+---------------+------------------+------------------+-------------------+---------+------------------+------------------+------------------+---------+-----------+--------------------+-------+
# |summary|                ID|              Age|   Sex|         Angina|    Blood_Pressure|       Cholesterol|           Glycemia|      ECG|        Heart_Rate|Angina_After_Sport|        ECG_Angina|ECG_Slope|Fluoroscopy|        Thalassaemia|Disease|
# +-------+------------------+-----------------+------+---------------+------------------+------------------+-------------------+---------+------------------+------------------+------------------+---------+-----------+--------------------+-------+
# |  count|               297|              297|   297|            297|               297|               297|                297|      297|               297|               297|               297|      297|        297|                 297|    297|
# |   mean|150.67340067340066|54.54208754208754|  null|           null|131.69360269360268|247.35016835016836|               null|     null| 149.5993265993266|              null|1.0555555555555558|     null|       null|                null|   null|
# | stddev| 87.32328332326846|9.049735681096765|  null|           null|17.762806366598998| 51.99758253513896|               null|     null|22.941562061360802|              null|1.1661227818468953|     null|       null|                null|   null|
# |    min|                 1|             29.0|Female|   Asymptomatic|              94.0|             126.0|Less than 120 mg/dl|Anomalies|              71.0|                No|               0.0|  Falling|       High|                  No|     No|
# |    max|               302|             77.0|  Male|Unstable angina|             200.0|             564.0|More than 120 mg/dl|   Normal|             202.0|               Yes|               6.2|   Stable| No anomaly|Unstable Thalassa...|    Yes|
# +-------+------------------+-----------------+------+---------------+------------------+------------------+-------------------+---------+------------------+------------------+------------------+---------+-----------+--------------------+-------+

# %%
# Descriptive statistics of categorical variables
data.groupBy("Disease").count().withColumn("Percentage", round((col("count") / data.count()) * 100, 2)).show()
data.groupBy("Sex").count().withColumn("Percentage", round((col("count") / data.count()) * 100, 2)).show()
data.groupBy("Angina").count().withColumn("Percentage", round((col("count") / data.count()) * 100, 2)).show()
data.groupBy("Glycemia").count().withColumn("Percentage", round((col("count") / data.count()) * 100, 2)).show()
# Out:
# +-------+-----+----------+
# |Disease|count|Percentage|
# +-------+-----+----------+
# |     No|  160|     53.87|
# |    Yes|  137|     46.13|
# +-------+-----+----------+
#
# +------+-----+----------+
# |   Sex|count|Percentage|
# +------+-----+----------+
# |Female|   96|     32.32|
# |  Male|  201|     67.68|
# +------+-----+----------+
#
# +---------------+-----+----------+
# |         Angina|count|Percentage|
# +---------------+-----+----------+
# |    Other pains|   83|     27.95|
# |Unstable angina|   49|      16.5|
# |  Stable angina|   23|      7.74|
# |   Asymptomatic|  142|     47.81|
# +---------------+-----+----------+
#
# +-------------------+-----+----------+
# |           Glycemia|count|Percentage|
# +-------------------+-----+----------+
# |More than 120 mg/dl|   43|     14.48|
# |Less than 120 mg/dl|  254|     85.52|
# +-------------------+-----+----------+

# %%
# Descriptive statistics of numerical variables
data.select(data['Age']).summary().show()
data.select(data['Blood_Pressure']).summary().show()
data.select(data['Cholesterol']).summary().show()
data.select(data['Heart_Rate']).summary().show()
# Out:
# +-------+-----------------+
# |summary|              Age|
# +-------+-----------------+
# |  count|              297|
# |   mean|54.54208754208754|
# | stddev|9.049735681096765|
# |    min|             29.0|
# |    25%|             48.0|
# |    50%|             56.0|
# |    75%|             61.0|
# |    max|             77.0|
# +-------+-----------------+
#
# +-------+------------------+
# |summary|    Blood_Pressure|
# +-------+------------------+
# |  count|               297|
# |   mean|131.69360269360268|
# | stddev|17.762806366598998|
# |    min|              94.0|
# |    25%|             120.0|
# |    50%|             130.0|
# |    75%|             140.0|
# |    max|             200.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|       Cholesterol|
# +-------+------------------+
# |  count|               297|
# |   mean|247.35016835016836|
# | stddev| 51.99758253513896|
# |    min|             126.0|
# |    25%|             211.0|
# |    50%|             243.0|
# |    75%|             276.0|
# |    max|             564.0|
# +-------+------------------+
#
# +-------+------------------+
# |summary|        Heart_Rate|
# +-------+------------------+
# |  count|               297|
# |   mean| 149.5993265993266|
# | stddev|22.941562061360802|
# |    min|              71.0|
# |    25%|             133.0|
# |    50%|             153.0|
# |    75%|             166.0|
# |    max|             202.0|
# +-------+------------------+

# %%
# Cross tabulation of categorical variables
data.groupBy('Sex', 'Disease').count().show()
data.groupBy('Angina', 'Disease').count().show()
data.groupBy('Glycemia', 'Disease').count().show()
# Out:
# +------+-------+-----+
# |   Sex|Disease|count|
# +------+-------+-----+
# |  Male|     No|   89|
# |  Male|    Yes|  112|
# |Female|     No|   71|
# |Female|    Yes|   25|
# +------+-------+-----+
#
# +---------------+-------+-----+
# |         Angina|Disease|count|
# +---------------+-------+-----+
# |   Asymptomatic|     No|   39|
# |  Stable angina|     No|   16|
# |  Stable angina|    Yes|    7|
# |   Asymptomatic|    Yes|  103|
# |    Other pains|     No|   65|
# |Unstable angina|     No|   40|
# |    Other pains|    Yes|   18|
# |Unstable angina|    Yes|    9|
# +---------------+-------+-----+
#
# +-------------------+-------+-----+
# |           Glycemia|Disease|count|
# +-------------------+-------+-----+
# |More than 120 mg/dl|    Yes|   20|
# |Less than 120 mg/dl|    Yes|  117|
# |Less than 120 mg/dl|     No|  137|
# |More than 120 mg/dl|     No|   23|
# +-------------------+-------+-----+

# %%
# Average of quantitative variables based on 'Disease'
data.groupBy('Disease').agg(round(mean('Age'), 2).alias('Age Average')).show()
data.groupBy('Disease').agg(round(mean('Blood_Pressure'), 2).alias('Blood Pressure Average')).show()
data.groupBy('Disease').agg(round(mean('Cholesterol'), 2).alias('Cholesterol Average')).show()
# Out:
# +-------+-----------+
# |Disease|Age Average|
# +-------+-----------+
# |     No|      52.64|
# |    Yes|      56.76|
# +-------+-----------+
#
# +-------+----------------------+
# |Disease|Blood Pressure Average|
# +-------+----------------------+
# |     No|                129.18|
# |    Yes|                134.64|
# +-------+----------------------+
#
# +-------+-------------------+
# |Disease|Cholesterol Average|
# +-------+-------------------+
# |     No|             243.49|
# |    Yes|             251.85|
# +-------+-------------------+

# %%
# Preview of the data
data.toPandas()
# Out:
#       ID   Age     Sex           Angina  Blood_Pressure  Cholesterol  \
# 0      1  63.0    Male    Stable angina           145.0        233.0
# 1      2  67.0    Male     Asymptomatic           160.0        286.0
# 2      3  67.0    Male     Asymptomatic           120.0        229.0
# 3      4  37.0    Male      Other pains           130.0        250.0
# 4      5  41.0  Female  Unstable angina           130.0        204.0
# ..   ...   ...     ...              ...             ...          ...
# 292  298  57.0  Female     Asymptomatic           140.0        241.0
# 293  299  45.0    Male    Stable angina           110.0        264.0
# 294  300  68.0    Male     Asymptomatic           144.0        193.0
# 295  301  57.0    Male     Asymptomatic           130.0        131.0
# 296  302  57.0  Female  Unstable angina           130.0        236.0
#
#                 Glycemia          ECG  Heart_Rate Angina_After_Sport  \
# 0    More than 120 mg/dl  Hypertrophy       150.0                 No
# 1    Less than 120 mg/dl  Hypertrophy       108.0                Yes
# 2    Less than 120 mg/dl  Hypertrophy       129.0                Yes
# 3    Less than 120 mg/dl       Normal       187.0                 No
# 4    Less than 120 mg/dl  Hypertrophy       172.0                 No
# ..                   ...          ...         ...                ...
# 292  Less than 120 mg/dl       Normal       123.0                Yes
# 293  Less than 120 mg/dl       Normal       132.0                 No
# 294  More than 120 mg/dl       Normal       141.0                 No
# 295  Less than 120 mg/dl       Normal       115.0                Yes
# 296  Less than 120 mg/dl  Hypertrophy       174.0                 No
#
#      ECG_Angina ECG_Slope Fluoroscopy                Thalassaemia Disease
# 0           2.3   Falling  No anomaly  Thalassaemia under control      No
# 1           1.5    Stable        High                          No     Yes
# 2           2.6    Stable      Medium       Unstable Thalassaemia     Yes
# 3           3.5   Falling  No anomaly                          No      No
# 4           1.4    Rising  No anomaly                          No      No
# ..          ...       ...         ...                         ...     ...
# 292         0.2    Stable  No anomaly       Unstable Thalassaemia     Yes
# 293         1.2    Stable  No anomaly       Unstable Thalassaemia     Yes
# 294         3.4    Stable      Medium       Unstable Thalassaemia     Yes
# 295         1.2    Stable         Low       Unstable Thalassaemia     Yes
# 296         0.0    Stable         Low                          No     Yes
#
# [297 rows x 15 columns]

# %%
# Conversion of categorical columns to numerical form
indexer1 = StringIndexer(inputCol = "Sex", outputCol = "Sex_Index")
indexer2 = StringIndexer(inputCol = "Angina", outputCol = "Angina_Index")
indexer3 = StringIndexer(inputCol = "Glycemia", outputCol = "Glycemia_Index")
indexer4 = StringIndexer(inputCol = "ECG", outputCol = "ECG_Index")
indexer5 = StringIndexer(inputCol = "Angina_After_Sport", outputCol = "Angina_After_Sport_Index")
indexer6 = StringIndexer(inputCol = "ECG_Slope", outputCol = "ECG_Slope_Index")
indexer7 = StringIndexer(inputCol = "Fluoroscopy", outputCol = "Fluoroscopy_Index")
indexer8 = StringIndexer(inputCol = "Thalassaemia", outputCol = "Thalassaemia_Index")
indexer9 = StringIndexer(inputCol = "Disease", outputCol = "label")

# Assemble feature columns into a feature vector
assembler = VectorAssembler(
    inputCols = ["Sex_Index", "Angina_Index", "Glycemia_Index", "ECG_Index", "Angina_After_Sport_Index", "ECG_Slope_Index", "Fluoroscopy_Index", "Thalassaemia_Index", "Age", "Blood_Pressure", "Cholesterol", "Heart_Rate", "ECG_Angina"],
    outputCol = "features"
)

# %%
# Logistic regression model definition
lr = LogisticRegression()

# Pipeline definition
pipeline = Pipeline(stages = [indexer1, indexer2, indexer3, indexer4, indexer5, indexer6, indexer7, indexer8, indexer9, assembler, lr])

# Split data into training and test sets
train_data, test_data = data.randomSplit([0.7, 0.3], seed = 123)

# Model training
model = pipeline.fit(train_data)

# %%
# Preview of the train data
train_data.toPandas()
# Out:
#       ID   Age     Sex           Angina  Blood_Pressure  Cholesterol  \
# 0      1  63.0    Male    Stable angina           145.0        233.0
# 1      2  67.0    Male     Asymptomatic           160.0        286.0
# 2      4  37.0    Male      Other pains           130.0        250.0
# 3      5  41.0  Female  Unstable angina           130.0        204.0
# 4      6  56.0    Male  Unstable angina           120.0        236.0
# ..   ...   ...     ...              ...             ...          ...
# 205  296  41.0    Male  Unstable angina           120.0        157.0
# 206  297  59.0    Male     Asymptomatic           164.0        176.0
# 207  300  68.0    Male     Asymptomatic           144.0        193.0
# 208  301  57.0    Male     Asymptomatic           130.0        131.0
# 209  302  57.0  Female  Unstable angina           130.0        236.0
#
#                 Glycemia          ECG  Heart_Rate Angina_After_Sport  \
# 0    More than 120 mg/dl  Hypertrophy       150.0                 No
# 1    Less than 120 mg/dl  Hypertrophy       108.0                Yes
# 2    Less than 120 mg/dl       Normal       187.0                 No
# 3    Less than 120 mg/dl  Hypertrophy       172.0                 No
# 4    Less than 120 mg/dl       Normal       178.0                 No
# ..                   ...          ...         ...                ...
# 205  Less than 120 mg/dl       Normal       182.0                 No
# 206  More than 120 mg/dl  Hypertrophy        90.0                 No
# 207  More than 120 mg/dl       Normal       141.0                 No
# 208  Less than 120 mg/dl       Normal       115.0                Yes
# 209  Less than 120 mg/dl  Hypertrophy       174.0                 No
#
#      ECG_Angina ECG_Slope Fluoroscopy                Thalassaemia Disease
# 0           2.3   Falling  No anomaly  Thalassaemia under control      No
# 1           1.5    Stable        High                          No     Yes
# 2           3.5   Falling  No anomaly                          No      No
# 3           1.4    Rising  No anomaly                          No      No
# 4           0.8    Rising  No anomaly                          No      No
# ..          ...       ...         ...                         ...     ...
# 205         0.0    Rising  No anomaly                          No      No
# 206         1.0    Stable      Medium  Thalassaemia under control     Yes
# 207         3.4    Stable      Medium       Unstable Thalassaemia     Yes
# 208         1.2    Stable         Low       Unstable Thalassaemia     Yes
# 209         0.0    Stable         Low                          No     Yes
#
# [210 rows x 15 columns]

# %%
# Preview of the test data
test_data.toPandas()
# Out:
#      ID   Age     Sex           Angina  Blood_Pressure  Cholesterol  \
# 0     3  67.0    Male     Asymptomatic           120.0        229.0
# 1     7  62.0  Female     Asymptomatic           140.0        268.0
# 2    10  53.0    Male     Asymptomatic           140.0        203.0
# 3    13  56.0    Male      Other pains           130.0        256.0
# 4    14  44.0    Male  Unstable angina           120.0        263.0
# ..  ...   ...     ...              ...             ...          ...
# 82  290  56.0    Male  Unstable angina           120.0        240.0
# 83  291  67.0    Male      Other pains           152.0        212.0
# 84  294  63.0    Male     Asymptomatic           140.0        187.0
# 85  298  57.0  Female     Asymptomatic           140.0        241.0
# 86  299  45.0    Male    Stable angina           110.0        264.0
#
#                Glycemia          ECG  Heart_Rate Angina_After_Sport  \
# 0   Less than 120 mg/dl  Hypertrophy       129.0                Yes
# 1   Less than 120 mg/dl  Hypertrophy       160.0                 No
# 2   More than 120 mg/dl  Hypertrophy       155.0                Yes
# 3   More than 120 mg/dl  Hypertrophy       142.0                Yes
# 4   Less than 120 mg/dl       Normal       173.0                 No
# ..                  ...          ...         ...                ...
# 82  Less than 120 mg/dl       Normal       169.0                 No
# 83  Less than 120 mg/dl  Hypertrophy       150.0                 No
# 84  Less than 120 mg/dl  Hypertrophy       144.0                Yes
# 85  Less than 120 mg/dl       Normal       123.0                Yes
# 86  Less than 120 mg/dl       Normal       132.0                 No
#
#     ECG_Angina ECG_Slope Fluoroscopy                Thalassaemia Disease
# 0          2.6    Stable      Medium       Unstable Thalassaemia     Yes
# 1          3.6   Falling      Medium                          No     Yes
# 2          3.1   Falling  No anomaly       Unstable Thalassaemia     Yes
# 3          0.6    Stable         Low  Thalassaemia under control     Yes
# 4          0.0    Rising  No anomaly       Unstable Thalassaemia      No
# ..         ...       ...         ...                         ...     ...
# 82         0.0   Falling  No anomaly                          No      No
# 83         0.8    Stable  No anomaly       Unstable Thalassaemia     Yes
# 84         4.0    Rising      Medium       Unstable Thalassaemia     Yes
# 85         0.2    Stable  No anomaly       Unstable Thalassaemia     Yes
# 86         1.2    Stable  No anomaly       Unstable Thalassaemia     Yes
#
# [87 rows x 15 columns]

# %%
# Prediction on test set
predictions = model.transform(test_data)

# Preview of predictions compared to actual values
predictions_pd = predictions.select("label", "prediction")
predictions_pd.toPandas()
# Out:
#     label  prediction
# 0     1.0         1.0
# 1     1.0         1.0
# 2     1.0         1.0
# 3     1.0         1.0
# 4     0.0         0.0
# ..    ...         ...
# 82    0.0         0.0
# 83    1.0         1.0
# 84    1.0         1.0
# 85    1.0         0.0
# 86    1.0         0.0
#
# [87 rows x 2 columns]

# %%
# Model accuracy calculation
evaluator = MulticlassClassificationEvaluator(labelCol = "label", predictionCol = "prediction", metricName = "accuracy")
accuracy = evaluator.evaluate(predictions)
print("Accuracy : {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy : 83.91%

# %%
# Confusion matrix display
predictions.select("label", "prediction").crosstab("label", "prediction").show()
# Out:
# +----------------+---+---+
# |label_prediction|0.0|1.0|
# +----------------+---+---+
# |             1.0|  7| 37|
# |             0.0| 36|  7|
# +----------------+---+---+
